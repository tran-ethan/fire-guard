# %% [markdown]
# # Data preparation
# This notebook merges the [Canadian Wildfire Dataset](https://www.kaggle.com/datasets/ulasozdemir/wildfires-in-canada-19502021) from Kaggle and [Canadian Wildland Fire Information System](https://cwfis.cfs.nrcan.gc.ca/downloads/activefires/) with weather data from Environment and Climate Change Canada (ECCC) and Meteorological Service of Canada (MSC) by using the [MSC GeoMet API](https://eccc-msc.github.io/open-data/msc-geomet/readme_en/)

# %%
from owslib.ogcapi.features import Features
import numpy
import pandas as pd
import json
from datetime import date

# %% [markdown]
# # Middle point
# Getting average latitude and longitude from which to query a box of weather stations

# %%
wildfire_df = pd.read_csv('2000-2021+2023-2024.csv')
wildfire_df
# Out:
#        agency      lat       lon        date  hectares cause response_type
# 0          BC  50.9050 -126.9292  2000-03-10      6.00     H
# 1          BC  49.2971 -122.2321  2000-08-21      0.20     H
# 2          BC  55.8000 -124.8167  2005-06-20      0.01     L
# 3          BC  49.8770 -121.5730  2000-08-06      0.10     L
# 4          BC  49.0667 -121.8333  2000-07-28      0.10     H
# ...       ...      ...       ...         ...       ...   ...           ...
# 148756     AK  65.0282 -141.2460  2024-05-15      0.00   NaN           NaN
# 148757     BC  55.9370 -121.9170  2024-05-12    295.00   NaN           FUL
# 148758     PC  60.2150 -112.8720  2024-04-26      0.10   NaN           FUL
# 148759     PC  60.1950 -112.7960  2024-04-26      0.10   NaN           FUL
# 148760     NT  60.3920 -117.8960  2024-05-05      3.00   NaN           FUL
#
# [148761 rows x 7 columns]

# %%
avg_lat = wildfire_df['lat'].mean()
avg_lon = wildfire_df['lon'].mean()
print('Average latitude: ' + str(avg_lat))
print('Average longitude: ' + str(avg_lon))
# Out:
# Average latitude: 52.032306654095855
# Average longitude: -102.52012118542373

# %% [markdown]
# # Querying MSC by using OGC API - Features Request
# Parameters to query

# %%
# Coordinate
lat = 52.032306654095855
lon = -102.52012118542373

# Buffer size (km)
buffer = 100

# Timeframe to query data
start_date = date(2000, 3, 10)
end_date = date(2024, 5, 5)
time_ = f"{start_date}/{end_date}"

# Bounding box
# The buffer needs to be transformed in degrees to get
# the coordinates of the corners of the bounding box:
# Latitude: 1 km ≈ 0.009°
# Longitude (at the 49th parallel): 1 km ≈ 0.014°
bbox = [
    lon - buffer * 0.02,
    lat - buffer * 0.01,
    lon + buffer * 0.02,
    lat + buffer * 0.01,
]

# %% [markdown]
# Retrieve [climate station data](https://api.weather.gc.ca/collections/climate-stations?lang=en) using [OWSLib](https://owslib.readthedocs.io/en/latest/)

# %%
features = Features('https://api.weather.gc.ca/')
station_data = features.collection_items(
    'climate-stations', bbox=bbox
)
station_json = json.dumps(station_data, indent=4)
print(station_json)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3336,
#                 "STATION_NAME": "STAR CITY",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 525200000,
#                 "LONGITUDE": -1042000000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "465.00",
#                 "CLIMATE_IDENTIFIER": "4057757",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1985-01-01 00:00:00",
#                 "LAST_DATE": "1992-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1985-07-01 00:00:00",
#                 "DLY_LAST_DATE": "1992-02-29 00:00:00",
#                 "MLY_FIRST_DATE": "1985-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1992-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -104.33333333333333,
#                     52.86666666666667
#                 ]
#             },
#             "id": "4057757"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3337,
#                 "STATION_NAME": "STAR CITY CDA EPF",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 524300000,
#                 "LONGITUDE": -1042000000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "469.10",
#                 "CLIMATE_IDENTIFIER": "4057760",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1951-01-01 00:00:00",
#                 "LAST_DATE": "1959-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1959-11-30 00:00:00",
#                 "MLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1959-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -104.33333333333333,
#                     52.71666666666667
#                 ]
#             },
#             "id": "4057760"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3529,
#                 "STATION_NAME": "ROBLIN",
#                 "PROV_STATE_TERR_CODE": "MB",
#                 "ENG_PROV_NAME": "MANITOBA",
#                 "FRE_PROV_NAME": "MANITOBA",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511400000,
#                 "LONGITUDE": -1012300000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "556.00",
#                 "CLIMATE_IDENTIFIER": "5012472",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "E",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 6,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1980-01-01 00:00:00",
#                 "LAST_DATE": "1997-03-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1980-04-01 00:00:00",
#                 "DLY_LAST_DATE": "1997-03-31 00:00:00",
#                 "MLY_FIRST_DATE": "1980-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1997-03-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -101.38333333333334,
#                     51.233333333333334
#                 ]
#             },
#             "id": "5012472"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3785,
#                 "STATION_NAME": "DURBAN CDA EPF",
#                 "PROV_STATE_TERR_CODE": "MB",
#                 "ENG_PROV_NAME": "MANITOBA",
#                 "FRE_PROV_NAME": "MANITOBA",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 515600000,
#                 "LONGITUDE": -1012400000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "419.10",
#                 "CLIMATE_IDENTIFIER": "5040840",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1954-01-01 00:00:00",
#                 "LAST_DATE": "1977-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1977-04-30 00:00:00",
#                 "MLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1977-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -101.4,
#                     51.93333333333333
#                 ]
#             },
#             "id": "5040840"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3808,
#                 "STATION_NAME": "KENVILLE EXP ST",
#                 "PROV_STATE_TERR_CODE": "MB",
#                 "ENG_PROV_NAME": "MANITOBA",
#                 "FRE_PROV_NAME": "MANITOBA",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 520000000,
#                 "LONGITUDE": -1011900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "387.40",
#                 "CLIMATE_IDENTIFIER": "5041440",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1951-01-01 00:00:00",
#                 "LAST_DATE": "1960-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1960-05-31 00:00:00",
#                 "MLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1960-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -101.31666666666666,
#                     52.0
#                 ]
#             },
#             "id": "5041440"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3827,
#                 "STATION_NAME": "MOUNTAIN GAP",
#                 "PROV_STATE_TERR_CODE": "MB",
#                 "ENG_PROV_NAME": "MANITOBA",
#                 "FRE_PROV_NAME": "MANITOBA",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 510800000,
#                 "LONGITUDE": -1004500000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "460.20",
#                 "CLIMATE_IDENTIFIER": "5041970",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "G",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1977-01-01 00:00:00",
#                 "LAST_DATE": "1977-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1977-07-01 00:00:00",
#                 "DLY_LAST_DATE": "1977-08-31 00:00:00",
#                 "MLY_FIRST_DATE": "1977-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1977-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -100.75,
#                     51.13333333333333
#                 ]
#             },
#             "id": "5041970"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2899,
#                 "STATION_NAME": "FENWOOD",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 510900000,
#                 "LONGITUDE": -1030400000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "624.80",
#                 "CLIMATE_IDENTIFIER": "4012483",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "A",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 1,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1973-01-01 00:00:00",
#                 "LAST_DATE": "2006-03-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1973-06-01 00:00:00",
#                 "DLY_LAST_DATE": "2006-03-31 00:00:00",
#                 "MLY_FIRST_DATE": "1973-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2006-03-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "Y",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.06666666666666,
#                     51.15
#                 ]
#             },
#             "id": "4012483"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2946,
#                 "STATION_NAME": "LEROSS",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511800000,
#                 "LONGITUDE": -1035200000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "676.40",
#                 "CLIMATE_IDENTIFIER": "4014320",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1940-01-01 00:00:00",
#                 "LAST_DATE": "1961-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1940-03-01 00:00:00",
#                 "DLY_LAST_DATE": "1961-03-31 00:00:00",
#                 "MLY_FIRST_DATE": "1940-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1961-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.86666666666666,
#                     51.3
#                 ]
#             },
#             "id": "4014320"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 6868,
#                 "STATION_NAME": "PARKERVIEW 2",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 512600000,
#                 "LONGITUDE": -1032400000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "649.00",
#                 "CLIMATE_IDENTIFIER": "4015875",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "G",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1993-01-01 00:00:00",
#                 "LAST_DATE": "1995-01-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1993-09-01 00:00:00",
#                 "DLY_LAST_DATE": "1995-01-31 00:00:00",
#                 "MLY_FIRST_DATE": "1993-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1995-01-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.4,
#                     51.43333333333333
#                 ]
#             },
#             "id": "4015875"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2984,
#                 "STATION_NAME": "PARKERVIEW",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 512411700,
#                 "LONGITUDE": -1031555100,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "637.00",
#                 "CLIMATE_IDENTIFIER": "4015870",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "E",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 6,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1979-01-01 00:00:00",
#                 "LAST_DATE": "2024-06-25 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1979-11-01 00:00:00",
#                 "DLY_LAST_DATE": "2024-06-25 00:00:00",
#                 "MLY_FIRST_DATE": "1979-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-09-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.26530555555556,
#                     51.40325
#                 ]
#             },
#             "id": "4015870"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2986,
#                 "STATION_NAME": "PASWEGIN",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 515900000,
#                 "LONGITUDE": -1035500000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "532.80",
#                 "CLIMATE_IDENTIFIER": "4015960",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "A",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 1,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1921-01-01 00:00:00",
#                 "LAST_DATE": "2003-09-30 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1921-03-01 00:00:00",
#                 "DLY_LAST_DATE": "2003-09-30 00:00:00",
#                 "MLY_FIRST_DATE": "1921-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2003-09-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "Y",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.91666666666667,
#                     51.983333333333334
#                 ]
#             },
#             "id": "4015960"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2989,
#                 "STATION_NAME": "PREECEVILLE",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 515700000,
#                 "LONGITUDE": -1023900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "518.20",
#                 "CLIMATE_IDENTIFIER": "4016185",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1970-01-01 00:00:00",
#                 "LAST_DATE": "1992-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1970-05-01 00:00:00",
#                 "DLY_LAST_DATE": "1992-10-31 00:00:00",
#                 "MLY_FIRST_DATE": "1970-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1992-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.65,
#                     51.95
#                 ]
#             },
#             "id": "4016185"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3025,
#                 "STATION_NAME": "SPALDING",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 522200000,
#                 "LONGITUDE": -1042200000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "578.10",
#                 "CLIMATE_IDENTIFIER": "4017704",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1990-01-01 00:00:00",
#                 "LAST_DATE": "1997-05-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1990-07-01 00:00:00",
#                 "DLY_LAST_DATE": "1997-05-31 00:00:00",
#                 "MLY_FIRST_DATE": "1990-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1997-05-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -104.36666666666666,
#                     52.36666666666667
#                 ]
#             },
#             "id": "4017704"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3436,
#                 "STATION_NAME": "DANBURY",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 520800000,
#                 "LONGITUDE": -1021200000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "512.10",
#                 "CLIMATE_IDENTIFIER": "4082072",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "G",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1972-01-01 00:00:00",
#                 "LAST_DATE": "1973-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1972-10-01 00:00:00",
#                 "DLY_LAST_DATE": "1973-07-31 00:00:00",
#                 "MLY_FIRST_DATE": "1972-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1973-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.2,
#                     52.13333333333333
#                 ]
#             },
#             "id": "4082072"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3439,
#                 "STATION_NAME": "HUDSON BAY A",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 524900000,
#                 "LONGITUDE": -1021900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "358.10",
#                 "CLIMATE_IDENTIFIER": "4083321",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "E",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 6,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1978-01-01 00:00:00",
#                 "LAST_DATE": "1999-04-06 17:00:00",
#                 "HLY_FIRST_DATE": "1978-09-01 00:00:00",
#                 "HLY_LAST_DATE": "1999-04-06 17:00:00",
#                 "DLY_FIRST_DATE": "1978-09-01 00:00:00",
#                 "DLY_LAST_DATE": "1993-06-30 00:00:00",
#                 "MLY_FIRST_DATE": "1978-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1993-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "Y"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.31666666666666,
#                     52.81666666666667
#                 ]
#             },
#             "id": "4083321"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3442,
#                 "STATION_NAME": "KELVINGTON EXP ST",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 521000000,
#                 "LONGITUDE": -1033100000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "594.40",
#                 "CLIMATE_IDENTIFIER": "4083736",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1951-01-01 00:00:00",
#                 "LAST_DATE": "1959-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1951-05-01 00:00:00",
#                 "DLY_LAST_DATE": "1959-06-30 00:00:00",
#                 "MLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1959-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.51666666666667,
#                     52.166666666666664
#                 ]
#             },
#             "id": "4083736"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3452,
#                 "STATION_NAME": "PORCUPINE PLAIN 2",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 523600000,
#                 "LONGITUDE": -1031500000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "498.30",
#                 "CLIMATE_IDENTIFIER": "4086161",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1953-01-01 00:00:00",
#                 "LAST_DATE": "1964-12-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1953-02-01 00:00:00",
#                 "DLY_LAST_DATE": "1964-12-31 00:00:00",
#                 "MLY_FIRST_DATE": "1953-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1964-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.25,
#                     52.6
#                 ]
#             },
#             "id": "4086161"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3453,
#                 "STATION_NAME": "PORCUPINE PLAIN 3",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 524500000,
#                 "LONGITUDE": -1031200000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": null,
#                 "CLIMATE_IDENTIFIER": "4086162",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1954-01-01 00:00:00",
#                 "LAST_DATE": "1954-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1954-06-30 00:00:00",
#                 "MLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1954-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.2,
#                     52.75
#                 ]
#             },
#             "id": "4086162"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3528,
#                 "STATION_NAME": "ROBLIN",
#                 "PROV_STATE_TERR_CODE": "MB",
#                 "ENG_PROV_NAME": "MANITOBA",
#                 "FRE_PROV_NAME": "MANITOBA",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511400000,
#                 "LONGITUDE": -1012300000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "556.00",
#                 "CLIMATE_IDENTIFIER": "5012471",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1969-01-01 00:00:00",
#                 "LAST_DATE": "1979-12-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1969-11-01 00:00:00",
#                 "DLY_LAST_DATE": "1979-12-31 00:00:00",
#                 "MLY_FIRST_DATE": "1969-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1979-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -101.38333333333334,
#                     51.233333333333334
#                 ]
#             },
#             "id": "5012471"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 44203,
#                 "STATION_NAME": "YORKTON",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511553000,
#                 "LONGITUDE": -1022742000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "498.30",
#                 "CLIMATE_IDENTIFIER": "4019085",
#                 "TC_IDENTIFIER": "YQV",
#                 "WMO_IDENTIFIER": "71138",
#                 "STATION_TYPE": "Aviation-Auto",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": null,
#                 "DISPLAY_CODE": null,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "2005-01-01 00:00:00",
#                 "LAST_DATE": "2011-08-25 12:00:00",
#                 "HLY_FIRST_DATE": "2005-04-01 01:00:00",
#                 "HLY_LAST_DATE": "2011-08-25 12:00:00",
#                 "DLY_FIRST_DATE": "2005-01-01 00:00:00",
#                 "DLY_LAST_DATE": "2011-08-25 00:00:00",
#                 "MLY_FIRST_DATE": "2005-09-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-11-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "Y"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.46166666666667,
#                     51.264722222222225
#                 ]
#             },
#             "id": "4019085"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3766,
#                 "STATION_NAME": "COWAN",
#                 "PROV_STATE_TERR_CODE": "MB",
#                 "ENG_PROV_NAME": "MANITOBA",
#                 "FRE_PROV_NAME": "MANITOBA",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 520200000,
#                 "LONGITUDE": -1003900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "365.80",
#                 "CLIMATE_IDENTIFIER": "5040FJ3",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "D",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 5,
#                 "ENG_STN_OPERATOR_ACRONYM": "CCN",
#                 "FRE_STN_OPERATOR_ACRONYM": "RCSC",
#                 "ENG_STN_OPERATOR_NAME": "Co-operative Climate Network",
#                 "FRE_STN_OPERATOR_NAME": "R\u00e9seau coop\u00e9ratif de stations climatiques",
#                 "FIRST_DATE": "1984-01-01 00:00:00",
#                 "LAST_DATE": "2023-05-18 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1984-06-01 00:00:00",
#                 "DLY_LAST_DATE": "2023-05-18 00:00:00",
#                 "MLY_FIRST_DATE": "1984-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-11-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "Y",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -100.65,
#                     52.03333333333333
#                 ]
#             },
#             "id": "5040FJ3"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 7550,
#                 "STATION_NAME": "HUDSON BAY",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 524900000,
#                 "LONGITUDE": -1021900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "358.10",
#                 "CLIMATE_IDENTIFIER": "4083322",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Aviation-Auto",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": null,
#                 "DISPLAY_CODE": null,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1992-12-01 00:00:00",
#                 "LAST_DATE": "2007-08-31 00:00:00",
#                 "HLY_FIRST_DATE": "1994-02-01 01:00:00",
#                 "HLY_LAST_DATE": "2007-07-24 08:00:00",
#                 "DLY_FIRST_DATE": "1992-12-01 00:00:00",
#                 "DLY_LAST_DATE": "2007-08-31 00:00:00",
#                 "MLY_FIRST_DATE": "2001-12-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-08-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "Y"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.31666666666666,
#                     52.81666666666667
#                 ]
#             },
#             "id": "4083322"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3061,
#                 "STATION_NAME": "YORKTON",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511100000,
#                 "LONGITUDE": -1023100000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "497.70",
#                 "CLIMATE_IDENTIFIER": "4019070",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1884-01-01 00:00:00",
#                 "LAST_DATE": "1945-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1884-02-01 00:00:00",
#                 "DLY_LAST_DATE": "1945-10-31 00:00:00",
#                 "MLY_FIRST_DATE": "1884-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1945-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.51666666666667,
#                     51.18333333333333
#                 ]
#             },
#             "id": "4019070"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3062,
#                 "STATION_NAME": "YORKTON A",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511600000,
#                 "LONGITUDE": -1022800000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "498.30",
#                 "CLIMATE_IDENTIFIER": "4019080",
#                 "TC_IDENTIFIER": "YQV",
#                 "WMO_IDENTIFIER": "71138",
#                 "STATION_TYPE": "Aviation-Staffed",
#                 "NORMAL_CODE": "A",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 1,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1941-01-01 00:00:00",
#                 "LAST_DATE": "2005-10-31 00:00:00",
#                 "HLY_FIRST_DATE": "1953-01-01 00:00:00",
#                 "HLY_LAST_DATE": "2005-10-05 00:00:00",
#                 "DLY_FIRST_DATE": "1941-05-01 00:00:00",
#                 "DLY_LAST_DATE": "2005-10-31 00:00:00",
#                 "MLY_FIRST_DATE": "1941-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2005-10-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "Y",
#                 "HAS_HOURLY_DATA": "Y"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.46666666666667,
#                     51.266666666666666
#                 ]
#             },
#             "id": "4019080"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3063,
#                 "STATION_NAME": "YORKTON CDA EPF",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 510800000,
#                 "LONGITUDE": -1022500000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "503.80",
#                 "CLIMATE_IDENTIFIER": "4019090",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "G",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1951-01-01 00:00:00",
#                 "LAST_DATE": "1972-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1951-11-01 00:00:00",
#                 "DLY_LAST_DATE": "1972-05-31 00:00:00",
#                 "MLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1972-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.41666666666667,
#                     51.13333333333333
#                 ]
#             },
#             "id": "4019090"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 26999,
#                 "STATION_NAME": "TONKIN",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 511200000,
#                 "LONGITUDE": -1021400000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "526.70",
#                 "CLIMATE_IDENTIFIER": "4019082",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1994-01-01 00:00:00",
#                 "LAST_DATE": "2016-01-13 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1994-07-01 00:00:00",
#                 "DLY_LAST_DATE": "2016-01-13 00:00:00",
#                 "MLY_FIRST_DATE": "1994-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-11-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.23333333333333,
#                     51.2
#                 ]
#             },
#             "id": "4019082"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3428,
#                 "STATION_NAME": "TISDALE",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 525200000,
#                 "LONGITUDE": -1040000000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "449.90",
#                 "CLIMATE_IDENTIFIER": "4078080",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "G",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 8,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1954-01-01 00:00:00",
#                 "LAST_DATE": "1981-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1954-04-01 00:00:00",
#                 "DLY_LAST_DATE": "1981-09-30 00:00:00",
#                 "MLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1981-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -104.0,
#                     52.86666666666667
#                 ]
#             },
#             "id": "4078080"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3429,
#                 "STATION_NAME": "VALPARAISO",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 524700000,
#                 "LONGITUDE": -1041200000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "461.80",
#                 "CLIMATE_IDENTIFIER": "4078415",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "G",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
# ...
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1958-08-31 00:00:00",
#                 "MLY_FIRST_DATE": "1954-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1958-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.73333333333333,
#                     51.71666666666667
#                 ]
#             },
#             "id": "4010960"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2872,
#                 "STATION_NAME": "COTE",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 513100000,
#                 "LONGITUDE": -1014700000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "449.60",
#                 "CLIMATE_IDENTIFIER": "4011846",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "A",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 1,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1970-01-01 00:00:00",
#                 "LAST_DATE": "2006-03-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1970-06-01 00:00:00",
#                 "DLY_LAST_DATE": "2006-03-31 00:00:00",
#                 "MLY_FIRST_DATE": "1970-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2006-03-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "Y",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -101.78333333333333,
#                     51.516666666666666
#                 ]
#             },
#             "id": "4011846"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2928,
#                 "STATION_NAME": "INSINGER",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 513200000,
#                 "LONGITUDE": -1030500000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "538.90",
#                 "CLIMATE_IDENTIFIER": "4013518",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1979-01-01 00:00:00",
#                 "LAST_DATE": "1987-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1979-02-01 00:00:00",
#                 "DLY_LAST_DATE": "1987-11-30 00:00:00",
#                 "MLY_FIRST_DATE": "1979-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1987-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.08333333333333,
#                     51.53333333333333
#                 ]
#             },
#             "id": "4013518"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 2993,
#                 "STATION_NAME": "QUILL LAKE",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 520400000,
#                 "LONGITUDE": -1041400000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "487.70",
#                 "CLIMATE_IDENTIFIER": "4016330",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": null,
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 9,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1911-01-01 00:00:00",
#                 "LAST_DATE": "1943-12-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1911-06-01 00:00:00",
#                 "DLY_LAST_DATE": "1943-12-31 00:00:00",
#                 "MLY_FIRST_DATE": "1911-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1943-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -104.23333333333333,
#                     52.06666666666667
#                 ]
#             },
#             "id": "4016330"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3431,
#                 "STATION_NAME": "ARCHERWILL",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 522600000,
#                 "LONGITUDE": -1040100000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "556.00",
#                 "CLIMATE_IDENTIFIER": "4080200",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "E",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 6,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1951-01-01 00:00:00",
#                 "LAST_DATE": "1982-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1982-11-30 00:00:00",
#                 "MLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1982-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -104.01666666666667,
#                     52.43333333333333
#                 ]
#             },
#             "id": "4080200"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3446,
#                 "STATION_NAME": "MCKAGUE 2",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 523500000,
#                 "LONGITUDE": -1035000000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "543.00",
#                 "CLIMATE_IDENTIFIER": "4085052",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "E",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 6,
#                 "ENG_STN_OPERATOR_ACRONYM": "CCN",
#                 "FRE_STN_OPERATOR_ACRONYM": "RCSC",
#                 "ENG_STN_OPERATOR_NAME": "Co-operative Climate Network",
#                 "FRE_STN_OPERATOR_NAME": "R\u00e9seau coop\u00e9ratif de stations climatiques",
#                 "FIRST_DATE": "1985-01-01 00:00:00",
#                 "LAST_DATE": "2019-03-24 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1985-07-01 00:00:00",
#                 "DLY_LAST_DATE": "2019-03-24 00:00:00",
#                 "MLY_FIRST_DATE": "1985-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-11-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.83333333333333,
#                     52.583333333333336
#                 ]
#             },
#             "id": "4085052"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3448,
#                 "STATION_NAME": "PELLY",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 520500000,
#                 "LONGITUDE": -1015200000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "509.00",
#                 "CLIMATE_IDENTIFIER": "4086000",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "Climate-Staffed",
#                 "NORMAL_CODE": "A",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 1,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1951-01-01 00:00:00",
#                 "LAST_DATE": "2016-03-20 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1951-07-01 00:00:00",
#                 "DLY_LAST_DATE": "2016-03-20 00:00:00",
#                 "MLY_FIRST_DATE": "1951-01-01 00:00:00",
#                 "MLY_LAST_DATE": "2007-11-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "N",
#                 "HAS_NORMALS_DATA": "Y",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -101.86666666666666,
#                     52.083333333333336
#                 ]
#             },
#             "id": "4086000"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3451,
#                 "STATION_NAME": "PORCUPINE PLAIN",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 523900000,
#                 "LONGITUDE": -1030900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "464.80",
#                 "CLIMATE_IDENTIFIER": "4086160",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "E",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 6,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1953-01-01 00:00:00",
#                 "LAST_DATE": "1995-08-31 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1953-01-01 00:00:00",
#                 "DLY_LAST_DATE": "1995-08-31 00:00:00",
#                 "MLY_FIRST_DATE": "1953-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1995-08-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -103.15,
#                     52.65
#                 ]
#             },
#             "id": "4086160"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "STN_ID": 3454,
#                 "STATION_NAME": "PRAIRIE RIVER",
#                 "PROV_STATE_TERR_CODE": "SK",
#                 "ENG_PROV_NAME": "SASKATCHEWAN",
#                 "FRE_PROV_NAME": "SASKATCHEWAN",
#                 "COUNTRY": "CAN",
#                 "LATITUDE": 525200000,
#                 "LONGITUDE": -1025900000,
#                 "TIMEZONE": "CST",
#                 "ELEVATION": "467.00",
#                 "CLIMATE_IDENTIFIER": "4086180",
#                 "TC_IDENTIFIER": null,
#                 "WMO_IDENTIFIER": null,
#                 "STATION_TYPE": "N/A",
#                 "NORMAL_CODE": "F",
#                 "PUBLICATION_CODE": 1,
#                 "DISPLAY_CODE": 7,
#                 "ENG_STN_OPERATOR_ACRONYM": null,
#                 "FRE_STN_OPERATOR_ACRONYM": null,
#                 "ENG_STN_OPERATOR_NAME": null,
#                 "FRE_STN_OPERATOR_NAME": null,
#                 "FIRST_DATE": "1956-01-01 00:00:00",
#                 "LAST_DATE": "1982-12-01 00:00:00",
#                 "HLY_FIRST_DATE": null,
#                 "HLY_LAST_DATE": null,
#                 "DLY_FIRST_DATE": "1956-05-01 00:00:00",
#                 "DLY_LAST_DATE": "1982-07-31 00:00:00",
#                 "MLY_FIRST_DATE": "1956-01-01 00:00:00",
#                 "MLY_LAST_DATE": "1982-12-01 00:00:00",
#                 "HAS_MONTHLY_SUMMARY": "Y",
#                 "HAS_NORMALS_DATA": "N",
#                 "HAS_HOURLY_DATA": "N"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -102.98333333333333,
#                     52.86666666666667
#                 ]
#             },
#             "id": "4086180"
#         }
#     ],
#     "numberMatched": 104,
#     "numberReturned": 104,
#     "links": [
#         {
#             "type": "application/geo+json",
#             "rel": "self",
#             "title": "This document as GeoJSON",
#             "href": "https://api.weather.gc.ca/collections/climate-stations/items?f=json&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855"
#         },
#         {
#             "rel": "alternate",
#             "type": "application/ld+json",
#             "title": "This document as RDF (JSON-LD)",
#             "href": "https://api.weather.gc.ca/collections/climate-stations/items?f=jsonld&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855"
#         },
#         {
#             "type": "text/html",
#             "rel": "alternate",
#             "title": "This document as HTML",
#             "href": "https://api.weather.gc.ca/collections/climate-stations/items?f=html&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855"
#         },
#         {
#             "type": "application/json",
#             "title": "Climate Stations",
#             "rel": "collection",
#             "href": "https://api.weather.gc.ca/collections/climate-stations/items"
#         }
#     ],
#     "timeStamp": "2024-07-15T04:06:29.899640Z"
# }

# %%
# Number of stations within 50km of point
len(station_data['features'])
# Out:
# 104

# %%
# Create list of station IDs
stations = [station['properties']['STATION_NAME'] for station in station_data['features']]
stations
# Out:
# ['STAR CITY',
#  'STAR CITY CDA EPF',
#  'ROBLIN',
#  'DURBAN CDA EPF',
#  'KENVILLE EXP ST',
#  'MOUNTAIN GAP',
#  'FENWOOD',
#  'LEROSS',
#  'PARKERVIEW 2',
#  'PARKERVIEW',
#  'PASWEGIN',
#  'PREECEVILLE',
#  'SPALDING',
#  'DANBURY',
#  'HUDSON BAY A',
#  'KELVINGTON EXP ST',
#  'PORCUPINE PLAIN 2',
#  'PORCUPINE PLAIN 3',
#  'ROBLIN',
#  'YORKTON',
#  'COWAN',
#  'HUDSON BAY',
#  'YORKTON',
#  'YORKTON A',
#  'YORKTON CDA EPF',
#  'TONKIN',
#  'TISDALE',
#  'VALPARAISO',
#  'BERTWELL',
#  'HUDSON BAY 2',
#  'PLEASANTDALE',
#  'MAFEKING',
#  'SWAN RIVER',
#  'DYSART',
#  'LESTOCK',
#  'MARGO',
#  'PREECEVILLE 2',
#  'PINE RIVER',
#  'WYNYARD',
#  'ARMIT',
#  'LAC VERT',
#  'YORKTON',
#  'GRANDVIEW CDA EPF',
#  'LENSWOOD EXP ST',
#  'SWAN RIVER 2',
#  'HUBBARD',
#  'PUNNICHY',
#  'TISDALE SOUTH',
#  'VEREGIN',
#  'ROBLIN',
#  'LINTLAW',
#  'WEEKES',
#  'ROBLIN NORTH',
#  'HUDSON BAY(AUT)',
#  'YORKTON',
#  'BUCHANAN',
#  'KELLIHER',
#  'LIPTON 2',
#  'HUDSON BAY 13W',
#  'STORNOWAY',
#  'WYNYARD (AUT)',
#  'HUNTERS POINT MARINE',
#  'CROOKED RIVER',
#  'HUDSON BAY',
#  'MCKAGUE',
#  'PELLY 2',
#  'SOMME CDA EPF',
#  'NORQUAY',
#  'YORKTON RCMP SNOW',
#  'CANORA',
#  'FOAM LAKE',
#  'INSINGER',
#  'KAMSACK',
#  'ENDEAVOUR 2',
#  'THEODORE',
#  'TOGO',
#  'WISHART',
#  'SWAN RIVER RCS',
#  'ARRAN',
#  'PINE RIVER',
#  'DAFOE',
#  'FOAM LAKE',
#  'GOOD SPIRIT LAKE',
#  'KRISTNES',
#  'KUROKI',
#  'QUINTON',
#  'ROBLIN FRIESEN 3 NORTHWEST',
#  'SERATH',
#  'ARRAN 23N',
#  'ENDEAVOUR',
#  'KELVINGTON',
#  'MISTATIM',
#  'BOGGY CREEK',
#  'BIRCH RIVER',
#  'GRANDVIEW',
#  'BUCHANAN',
#  'COTE',
#  'INSINGER',
#  'QUILL LAKE',
#  'ARCHERWILL',
#  'MCKAGUE 2',
#  'PELLY',
#  'PORCUPINE PLAIN',
#  'PRAIRIE RIVER']

# %% [markdown]
# Retrieving [daily climate observations](https://api.weather.gc.ca/collections/climate-daily/items?lang=en) using OWSLib

# %%
features = Features('https://api.weather.gc.ca/')
weather_data = features.collection_items(
    'climate-daily', bbox=bbox, datetime=time_
)
weather_json = json.dumps(weather_data, indent=4)
print(weather_json)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "id": "40190LN.2000.3.10",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 10,
#                 "MEAN_TEMPERATURE": -7.7,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 25.7,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-10 00:00:00",
#                 "MAX_TEMPERATURE": -5.1,
#                 "ID": "40190LN.2000.3.10",
#                 "MIN_TEMPERATURE": -10.3,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.11",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 11,
#                 "MEAN_TEMPERATURE": -11.1,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 29.1,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-11 00:00:00",
#                 "MAX_TEMPERATURE": -7.6,
#                 "ID": "40190LN.2000.3.11",
#                 "MIN_TEMPERATURE": -14.5,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.12",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 12,
#                 "MEAN_TEMPERATURE": -8.5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 26.5,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-12 00:00:00",
#                 "MAX_TEMPERATURE": -5.3,
#                 "ID": "40190LN.2000.3.12",
#                 "MIN_TEMPERATURE": -11.6,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.13",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 13,
#                 "MEAN_TEMPERATURE": -9.8,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 27.8,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-13 00:00:00",
#                 "MAX_TEMPERATURE": -6.2,
#                 "ID": "40190LN.2000.3.13",
#                 "MIN_TEMPERATURE": -13.4,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.14",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 14,
#                 "MEAN_TEMPERATURE": -16.1,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 34.1,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-14 00:00:00",
#                 "MAX_TEMPERATURE": -10.5,
#                 "ID": "40190LN.2000.3.14",
#                 "MIN_TEMPERATURE": -21.6,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.15",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 15,
#                 "MEAN_TEMPERATURE": -13.6,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 31.6,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-15 00:00:00",
#                 "MAX_TEMPERATURE": -6.8,
#                 "ID": "40190LN.2000.3.15",
#                 "MIN_TEMPERATURE": -20.3,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.16",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 16,
#                 "MEAN_TEMPERATURE": -11.1,
#                 "TOTAL_SNOW_FLAG": "E",
#                 "TOTAL_SNOW": 3,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 3,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 29.1,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-16 00:00:00",
#                 "MAX_TEMPERATURE": -3.1,
#                 "ID": "40190LN.2000.3.16",
#                 "MIN_TEMPERATURE": -19.1,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.17",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 17,
#                 "MEAN_TEMPERATURE": 0.4,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 17.6,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-17 00:00:00",
#                 "MAX_TEMPERATURE": 6.9,
#                 "ID": "40190LN.2000.3.17",
#                 "MIN_TEMPERATURE": -6.2,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.18",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 18,
#                 "MEAN_TEMPERATURE": 2.5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 15.5,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-18 00:00:00",
#                 "MAX_TEMPERATURE": 8.4,
#                 "ID": "40190LN.2000.3.18",
#                 "MIN_TEMPERATURE": -3.4,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.19",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 19,
#                 "MEAN_TEMPERATURE": 5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 13,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-19 00:00:00",
#                 "MAX_TEMPERATURE": 11.1,
#                 "ID": "40190LN.2000.3.19",
#                 "MIN_TEMPERATURE": -1.2,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.20",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 20,
#                 "MEAN_TEMPERATURE": 0.5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 17.5,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-20 00:00:00",
#                 "MAX_TEMPERATURE": 3.1,
#                 "ID": "40190LN.2000.3.20",
#                 "MIN_TEMPERATURE": -2.1,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.21",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 21,
#                 "MEAN_TEMPERATURE": 3.3,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 14.7,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-21 00:00:00",
#                 "MAX_TEMPERATURE": 10.4,
#                 "ID": "40190LN.2000.3.21",
#                 "MIN_TEMPERATURE": -3.8,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.22",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 22,
#                 "MEAN_TEMPERATURE": 1.5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 16.5,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-22 00:00:00",
#                 "MAX_TEMPERATURE": 11,
#                 "ID": "40190LN.2000.3.22",
#                 "MIN_TEMPERATURE": -8.1,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.23",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 23,
#                 "MEAN_TEMPERATURE": 10.4,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 7.6,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-23 00:00:00",
#                 "MAX_TEMPERATURE": 18.3,
#                 "ID": "40190LN.2000.3.23",
#                 "MIN_TEMPERATURE": 2.4,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.24",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 24,
#                 "MEAN_TEMPERATURE": 2.7,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 15.3,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-24 00:00:00",
#                 "MAX_TEMPERATURE": 6.3,
#                 "ID": "40190LN.2000.3.24",
#                 "MIN_TEMPERATURE": -1,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.25",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 25,
#                 "MEAN_TEMPERATURE": 2.9,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 15.1,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-25 00:00:00",
#                 "MAX_TEMPERATURE": 9.3,
#                 "ID": "40190LN.2000.3.25",
#                 "MIN_TEMPERATURE": -3.6,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.26",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 26,
#                 "MEAN_TEMPERATURE": 3.8,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 14.2,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-26 00:00:00",
#                 "MAX_TEMPERATURE": 9.2,
#                 "ID": "40190LN.2000.3.26",
#                 "MIN_TEMPERATURE": -1.6,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.27",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 27,
#                 "MEAN_TEMPERATURE": 0.2,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 17.8,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-27 00:00:00",
#                 "MAX_TEMPERATURE": 3.9,
#                 "ID": "40190LN.2000.3.27",
#                 "MIN_TEMPERATURE": -3.6,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.28",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 28,
#                 "MEAN_TEMPERATURE": 4.6,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 13.4,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-28 00:00:00",
#                 "MAX_TEMPERATURE": 12,
#                 "ID": "40190LN.2000.3.28",
#                 "MIN_TEMPERATURE": -2.8,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.29",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 9,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 29,
#                 "MEAN_TEMPERATURE": 4.1,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 9,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 13.9,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-29 00:00:00",
#                 "MAX_TEMPERATURE": 8.1,
#                 "ID": "40190LN.2000.3.29",
#                 "MIN_TEMPERATURE": 0,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.30",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 30,
#                 "MEAN_TEMPERATURE": 2.4,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 15.6,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-30 00:00:00",
#                 "MAX_TEMPERATURE": 5.6,
#                 "ID": "40190LN.2000.3.30",
#                 "MIN_TEMPERATURE": -0.8,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.3.31",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0.6,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 31,
#                 "MEAN_TEMPERATURE": 2.9,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0.6,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 15.1,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 3,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-03-31 00:00:00",
#                 "MAX_TEMPERATURE": 9.5,
#                 "ID": "40190LN.2000.3.31",
#                 "MIN_TEMPERATURE": -3.7,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.4.1",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 3,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 1,
#                 "MEAN_TEMPERATURE": 2.3,
#                 "TOTAL_SNOW_FLAG": "E",
#                 "TOTAL_SNOW": 1,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 4,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 15.7,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 4,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-04-01 00:00:00",
#                 "MAX_TEMPERATURE": 5.7,
#                 "ID": "40190LN.2000.4.1",
#                 "MIN_TEMPERATURE": -1.2,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.4.2",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 2,
#                 "MEAN_TEMPERATURE": 0,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 18,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 4,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-04-02 00:00:00",
#                 "MAX_TEMPERATURE": 3.8,
#                 "ID": "40190LN.2000.4.2",
#                 "MIN_TEMPERATURE": -3.8,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.4.3",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 3,
#                 "MEAN_TEMPERATURE": 0.5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 17.5,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 4,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-04-03 00:00:00",
#                 "MAX_TEMPERATURE": 6.2,
#                 "ID": "40190LN.2000.4.3",
#                 "MIN_TEMPERATURE": -5.3,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.4.4",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 4,
#                 "MEAN_TEMPERATURE": 5.2,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 12.8,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 4,
#                 "SNOW_ON_GROUND": null,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2000-04-04 00:00:00",
#                 "MAX_TEMPERATURE": 11.3,
#                 "ID": "40190LN.2000.4.4",
#                 "MIN_TEMPERATURE": -0.9,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2000.4.5",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2000,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 2,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 5,
#                 "MEAN_TEMPERATURE": -0.6,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 2,
#                 "SNOW_ON_GROUND_FLAG": "M",
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 18.6,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 4,
# ...
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 4.2,
#                 "COOLING_DEGREE_DAYS": 1.3,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 16,
#                 "MEAN_TEMPERATURE": 19.3,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 4.2,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-16 00:00:00",
#                 "MAX_TEMPERATURE": 23.3,
#                 "ID": "40190LN.2001.7.16",
#                 "MIN_TEMPERATURE": 15.3,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.17",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 5.4,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 17,
#                 "MEAN_TEMPERATURE": 23.4,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-17 00:00:00",
#                 "MAX_TEMPERATURE": 29.8,
#                 "ID": "40190LN.2001.7.17",
#                 "MIN_TEMPERATURE": 16.9,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.18",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 2.7,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 18,
#                 "MEAN_TEMPERATURE": 20.7,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-18 00:00:00",
#                 "MAX_TEMPERATURE": 25.3,
#                 "ID": "40190LN.2001.7.18",
#                 "MIN_TEMPERATURE": 16,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.19",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 3,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 19,
#                 "MEAN_TEMPERATURE": 21,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-19 00:00:00",
#                 "MAX_TEMPERATURE": 28.1,
#                 "ID": "40190LN.2001.7.19",
#                 "MIN_TEMPERATURE": 13.9,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.20",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 1.5,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 20,
#                 "MEAN_TEMPERATURE": 19.5,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-20 00:00:00",
#                 "MAX_TEMPERATURE": 27.4,
#                 "ID": "40190LN.2001.7.20",
#                 "MIN_TEMPERATURE": 11.5,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.21",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 0,
#                 "COOLING_DEGREE_DAYS": 3.2,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 21,
#                 "MEAN_TEMPERATURE": 21.2,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 0,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-21 00:00:00",
#                 "MAX_TEMPERATURE": 29.5,
#                 "ID": "40190LN.2001.7.21",
#                 "MIN_TEMPERATURE": 12.9,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.22",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 41.2,
#                 "COOLING_DEGREE_DAYS": 1,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 22,
#                 "MEAN_TEMPERATURE": 19,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 41.2,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 0,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-22 00:00:00",
#                 "MAX_TEMPERATURE": 25.1,
#                 "ID": "40190LN.2001.7.22",
#                 "MIN_TEMPERATURE": 12.9,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         },
#         {
#             "id": "40190LN.2001.7.23",
#             "type": "Feature",
#             "geometry": {
#                 "coordinates": [
#                     -104.2,
#                     51.766666666666666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "DIRECTION_MAX_GUST_FLAG": null,
#                 "LOCAL_YEAR": 2001,
#                 "MIN_REL_HUMIDITY": null,
#                 "SPEED_MAX_GUST_FLAG": null,
#                 "TOTAL_RAIN": 1,
#                 "COOLING_DEGREE_DAYS": 0,
#                 "COOLING_DEGREE_DAYS_FLAG": null,
#                 "LOCAL_DAY": 23,
#                 "MEAN_TEMPERATURE": 13.7,
#                 "TOTAL_SNOW_FLAG": null,
#                 "TOTAL_SNOW": 0,
#                 "MIN_REL_HUMIDITY_FLAG": null,
#                 "TOTAL_PRECIPITATION": 1,
#                 "SNOW_ON_GROUND_FLAG": null,
#                 "CLIMATE_IDENTIFIER": "40190LN",
#                 "HEATING_DEGREE_DAYS_FLAG": null,
#                 "MAX_REL_HUMIDITY": null,
#                 "MIN_TEMPERATURE_FLAG": null,
#                 "TOTAL_RAIN_FLAG": null,
#                 "MAX_TEMPERATURE_FLAG": null,
#                 "PROVINCE_CODE": "SK",
#                 "HEATING_DEGREE_DAYS": 4.3,
#                 "SPEED_MAX_GUST": null,
#                 "STATION_NAME": "WYNYARD (AUT)",
#                 "MEAN_TEMPERATURE_FLAG": null,
#                 "DIRECTION_MAX_GUST": null,
#                 "LOCAL_MONTH": 7,
#                 "SNOW_ON_GROUND": 0,
#                 "TOTAL_PRECIPITATION_FLAG": null,
#                 "LOCAL_DATE": "2001-07-23 00:00:00",
#                 "MAX_TEMPERATURE": 18.1,
#                 "ID": "40190LN.2001.7.23",
#                 "MIN_TEMPERATURE": 9.2,
#                 "MAX_REL_HUMIDITY_FLAG": null
#             }
#         }
#     ],
#     "numberMatched": 159306,
#     "numberReturned": 500,
#     "links": [
#         {
#             "type": "application/geo+json",
#             "rel": "self",
#             "title": "This document as GeoJSON",
#             "href": "https://api.weather.gc.ca/collections/climate-daily/items?f=json&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855&datetime=2000-03-10%2F2024-05-05"
#         },
#         {
#             "rel": "alternate",
#             "type": "application/ld+json",
#             "title": "This document as RDF (JSON-LD)",
#             "href": "https://api.weather.gc.ca/collections/climate-daily/items?f=jsonld&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855&datetime=2000-03-10%2F2024-05-05"
#         },
#         {
#             "type": "text/html",
#             "rel": "alternate",
#             "title": "This document as HTML",
#             "href": "https://api.weather.gc.ca/collections/climate-daily/items?f=html&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855&datetime=2000-03-10%2F2024-05-05"
#         },
#         {
#             "type": "application/geo+json",
#             "rel": "next",
#             "title": "items (next)",
#             "href": "https://api.weather.gc.ca/collections/climate-daily/items?offset=500&bbox=-104.52012118542373,51.032306654095855,-100.52012118542373,53.032306654095855&datetime=2000-03-10%2F2024-05-05"
#         },
#         {
#             "type": "application/json",
#             "title": "Daily Climate Observations",
#             "rel": "collection",
#             "href": "https://api.weather.gc.ca/collections/climate-daily/items"
#         }
#     ],
#     "timeStamp": "2024-07-15T04:54:55.886296Z"
# }

# %%
len(weather_data['features'])
# Out:
# 500
