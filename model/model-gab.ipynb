# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_no = pd.read_csv('2000-2021_nofires+weather.csv') # No wildfire
df_no['hectares'] = 0
df_yes = pd.read_csv('2000-2021_fires+weather.csv') # Wildfire dataset
df = pd.concat([df_yes, df_no])

# %%
df['class'] = (df.loc[:, 'hectares'] > 0).astype(int)

# %% [markdown]
# ## Feature Engineering
# We create a new column month, since from EDA month has a great impact on likelihood of wildfires

# %%
# We make a month column
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.month

# %%
df.head()
# Out:
#        lat       lon       date  hectares  elevation  temp_c  max_temp_c  \
# 0  56.7136 -110.4490 2000-01-01      0.20      347.0 -29.992     -25.265
# 1  54.7522 -114.9147 2000-01-03      0.30      827.0 -18.440     -13.971
# 2  53.6615 -102.1771 2000-01-06      0.30      264.0 -21.514     -18.139
# 3  51.0722 -115.3002 2000-01-07      0.50     1333.0  -8.396      -3.916
# 4  51.0668 -115.1288 2000-01-07      0.25     1283.0  -6.168      -1.646
#
#    min_temp_c  wind_kph  wind_dir  precip_mm  humidity  pressure_hPa  \
# 0     -33.665     9.470   242.195        0.0    72.753       971.810
# 1     -22.872     9.720   179.298        0.0    58.110       921.216
# 2     -22.889    10.163   265.019        0.0    77.443       985.953
# 3     -10.766    17.917   249.972        0.0    81.143       853.531
# 4      -8.895    17.917   249.972        0.0    72.987       860.034
#
#    soil_temp_c  soil_moisture  totalsnow_cm  class  month
# 0       -1.340          0.585           0.0      1      1
# 1       -8.824          0.558           0.0      1      1
# 2       -1.606          0.587           0.0      1      1
# 3        0.592          0.212           0.0      1      1
# 4       -3.393          0.290           0.0      1      1

# %%
df.describe()
# Out:
#                  lat            lon                           date  \
# count  173558.000000  173558.000000                         173558
# mean       52.763733    -112.071516  2010-10-16 07:05:38.971410176
# min        42.915700    -136.375000            1999-11-12 00:00:00
# 25%        50.153350    -120.154550            2005-06-21 00:00:00
# 50%        52.605000    -116.308767            2010-06-05 00:00:00
# 75%        55.446500    -110.771865            2015-09-19 00:00:00
# max        60.182700     -59.829412            2021-12-14 00:00:00
# std         3.491016      14.525921                            NaN
#
#             hectares      elevation         temp_c     max_temp_c  \
# count  173558.000000  173558.000000  173558.000000  173558.000000
# mean      129.177976     754.117874      10.660298      16.681407
# min         0.000000      -2.000000     -35.852000     -32.010000
# 25%         0.000000     404.000000       5.077000      10.735000
# 50%         0.000000     664.000000      12.233000      18.374000
# 75%         0.100000    1067.000000      17.572000      23.857750
# max    577646.800000    2799.000000      36.833000      46.762000
# std      3650.526019     460.432677       9.055219       9.518812
#
#           min_temp_c       wind_kph       wind_dir      precip_mm  \
# count  173558.000000  173558.000000  173558.000000  173558.000000
# mean        5.341760      13.848064     199.069128       1.282118
# min       -40.742000       1.800000       0.000000       0.000000
# 25%         0.149000       9.660000     134.372250       0.000000
# 50%         6.704000      12.965000     213.690000       0.000000
# 75%        11.779000      17.057000     266.595500       1.000000
# max        27.171000      61.924000     360.000000      78.300000
# std         8.553774       5.825417      90.185755       3.205991
#
#             humidity   pressure_hPa    soil_temp_c  soil_moisture  \
# count  173558.000000  173558.000000  173558.000000  173558.000000
# mean       63.524727     928.229820      10.039554       0.334743
# min        16.860000     717.632000     -19.478000       0.000000
# 25%        53.613000     893.092250       2.561250       0.244250
# 50%        63.341000     935.463500      11.236000       0.327000
# 75%        73.428000     965.850750      16.607000       0.396000
# max        99.987000    1040.466000      38.190000       0.764000
# std        13.538265      50.371736       7.792177       0.126900
#
#         totalsnow_cm          class          month
# count  173558.000000  173558.000000  173558.000000
# mean        0.159646       0.496808       5.747560
# min         0.000000       0.000000       1.000000
# 25%         0.000000       0.000000       5.000000
# 50%         0.000000       0.000000       6.000000
# 75%         0.000000       1.000000       7.000000
# max        30.100000       1.000000      12.000000
# std         0.884895       0.499991       1.821684

# %% [markdown]
# ## Train, test, validation
# Splitting dataset into train, test, validation, selecting input features and target columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Train, test, validation split
train_val_df, test_df = train_test_split(df, test_size=0.2, random_state=11)
train_df, val_df = train_test_split(train_val_df, test_size=0.25, random_state=11)

# %%
# Input and target columns
input_col = ['lat', 'lon', 'elevation', 'temp_c', 'max_temp_c', 'min_temp_c', 'wind_kph', 'precip_mm', 'humidity', 'pressure_hPa', 'soil_temp_c', 'soil_moisture', 'totalsnow_cm', 'month']
target_col = 'class'

# %%
# Create inputs and targets for train, test, validation sets
x_train = train_df[input_col].copy()
y_train = train_df[target_col].copy()
x_val = val_df[input_col].copy()
y_val = val_df[target_col].copy()
x_test = test_df[input_col].copy()
y_test = test_df[target_col].copy()

# %%
df.isna().sum()
# Out:
# lat              0
# lon              0
# date             0
# hectares         0
# elevation        0
# temp_c           0
# max_temp_c       0
# min_temp_c       0
# wind_kph         0
# wind_dir         0
# precip_mm        0
# humidity         0
# pressure_hPa     0
# soil_temp_c      0
# soil_moisture    0
# totalsnow_cm     0
# class            0
# month            0
# dtype: int64

# %% [markdown]
# ## Scaling features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler().fit(df[input_col])

# %%
x_train[input_col] = scaler.transform(x_train[input_col])
x_val[input_col] = scaler.transform(x_val[input_col])
x_test[input_col] = scaler.transform(x_test[input_col])

# %%
x_val.describe().loc[['min', 'max']]
# Out:
#           lat  lon  elevation    temp_c  max_temp_c  min_temp_c  wind_kph  \
# min  0.000000  0.0   0.000357  0.014804    0.012923    0.036076  0.000599
# max  0.990255  1.0   1.000000  0.951077    0.977352    0.975321  0.896597
#
#      precip_mm  humidity  pressure_hPa  soil_temp_c  soil_moisture  \
# min   0.000000  0.000000      0.000000     0.000329       0.000000
# max   0.904215  0.998977      0.994056     0.878685       0.997382
#
#      totalsnow_cm  month
# min      0.000000    0.0
# max      0.895349    1.0

# %% [markdown]
# ## Model Selection
# It is not evident which model would best be used for our dataset, so we perform simple tests to see if basic models might be viable using a single test-train split

# %% [markdown]
# ### Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.7117175946376784
# Train set Precision: 0.6976870551158284
# Train set Recall: 0.7429265752473528
# Train set f1: 0.7195964879506819
# ==============================================================
# Test set Accuracy: 0.7103307213643697
# Test set Precision: 0.6931366679366462
# Test set Recall: 0.7424790111940298
# Test set f1: 0.7169598874032371

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=11)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=11)

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.999951984942478
# Train set Precision: 1.0
# Train set Recall: 0.9999035661247083
# Train set f1: 0.999951780737369
# ==============================================================
# Test set Accuracy: 0.7248213874164554
# Test set Precision: 0.7223262344956705
# Test set Recall: 0.7197994402985075
# Test set f1: 0.7210606237589067

# %% [markdown]
# Decision Tree Regressor has overfit

# %% [markdown]
# ### Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(random_state=11)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=11)

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.9999327789194692
# Train set Precision: 0.9999228543876567
# Train set Recall: 0.9999421396748249
# Train set f1: 0.999932496938254
# ==============================================================
# Test set Accuracy: 0.8257374971191519
# Test set Precision: 0.8132016925246827
# Test set Recall: 0.8403684701492538
# Test set f1: 0.8265619175961235

# %% [markdown]
# ### Gradient Boosting Model

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model = GradientBoostingClassifier()
model.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.7578792709393666
# Train set Precision: 0.7416972160720119
# Train set Recall: 0.7882312098593994
# Train set f1: 0.7642565286907088
# ==============================================================
# Test set Accuracy: 0.750893062917723
# Test set Precision: 0.7326185657239758
# Test set Recall: 0.7808418843283582
# Test set f1: 0.7559619563683572

# %% [markdown]
# ### XGB Classifier

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)

accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.8457468262046978
# Train set Precision: 0.8296790360025058
# Train set Recall: 0.8684834808771625
# Train set f1: 0.8486379013032048
# ==============================================================
# Test set Accuracy: 0.8105554275178612
# Test set Precision: 0.7942354774093033
# Test set Recall: 0.832206156716418
# Test set f1: 0.8127775879740349

# %% [markdown]
# ### K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)

accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.8422129179710758
# Train set Precision: 0.835512106399909
# Train set Recall: 0.850546780072904
# Train set f1: 0.842962410757806
# ==============================================================
# Test set Accuracy: 0.7712894676192671
# Test set Precision: 0.7625833665849626
# Test set Recall: 0.7799673507462687
# Test set f1: 0.7711774030840178

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
# Predicting on the train set
y_pred_train = model.predict(x_train)

# Evaluating the model on the train set
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train   )

print(f"Train set Accuracy: {accuracy_train}")
print(f"Train set Precision: {precision_train}")
print(f"Train set Recall: {recall_train}")
print(f"Train set f1: {f1_train}")

print("==============================================================")
# Predicting on the test set
y_pred_test = model.predict(x_test)

accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print(f"Test set Accuracy: {accuracy_test}")
print(f"Test set Precision: {precision_test}")
print(f"Test set Recall: {recall_test}")
print(f"Test set f1: {f1_test}")
# Out:
# Train set Accuracy: 0.7495150479190275
# Train set Precision: 0.7321798684329098
# Train set Recall: 0.7835252367451638
# Train set f1: 0.7569828758827585
# ==============================================================
# Test set Accuracy: 0.7453042175616501
# Test set Precision: 0.7255359565807327
# Test set Recall: 0.7793843283582089
# Test set f1: 0.7514967535205329

# %% [markdown]
# It seems from this basic test that the random forests classifier performs the best on the dataset, so we will move forward with this model. However, it also seems like the XGB Classifier also works very well. So we will evaluate both models and tune both models to see which one would perform best after being fine-tuned.

# %% [markdown]
# ## Model evaluation

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(random_state=11)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=11)

# %%
model.score(x_train, y_train)
# Out:
# 0.9999327789194692

# %%
model.score(x_test, y_test)
# Out:
# 0.8257374971191519

# %% [markdown]
# Training accuracy is nearly 100%, but validation accuracy is only 80%. This indicates that the random forests has overfit to the training data. We also look at the probabilities for predictions using confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
def predict_and_plot(inputs, targets, name=''):
    preds = model.predict(inputs)
    
    accuracy = accuracy_score(targets, preds)
    print("Accuracy: {:.2f}%".format(accuracy * 100))
    
    cf = confusion_matrix(targets, preds, normalize='true')
    plt.figure()
    sns.heatmap(cf, annot=True)
    plt.xlabel('Prediction')
    plt.ylabel('Target')
    plt.title(f'{name} Confusion Matrix')
    
    return preds

# %%
train_preds = predict_and_plot(x_train, y_train, 'Training')
# Out:
# Accuracy: 99.99%

# %%
test_pred = predict_and_plot(x_test, y_test, 'Test')
# Out:
# Accuracy: 82.57%

# %%
val_pred = predict_and_plot(x_val, y_val, 'Validation')
# Out:
# Accuracy: 82.12%

# %%
importance_df = pd.DataFrame({
    'feature': x_train.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

# %%
plt.title('Feature Importance')
sns.barplot(data=importance_df, x='importance', y='feature');

# %% [markdown]
# ## Hyperparameter Tuning for random forests
# [Random forest classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %% [markdown]
# ### Max Depth

# %%
# Experiment with max depth
def max_depth_error(md):
    model = RandomForestClassifier(max_depth=md, random_state=11, n_jobs=-1)
    model.fit(x_train, y_train)
    train_acc = 1 - model.score(x_train, y_train)
    test_acc = 1 - model.score(x_test, y_test)
    return {'Max Depth': md, 'Training Error': train_acc, 'Test Error': test_acc}

# %%
errors_df = pd.DataFrame([max_depth_error(md) for md in range(1, 61)])

# %%
errors_df
# Out:
#     Max Depth  Training Error  Test Error
# 0           1        0.291634    0.293126
# 1           2        0.273657    0.275150
# 2           3        0.268644    0.270656
# 3           4        0.259569    0.260832
# 4           5        0.240037    0.243288
# 5           6        0.226842    0.232513
# 6           7        0.218132    0.224677
# 7           8        0.208433    0.218051
# 8           9        0.198907    0.211944
# 9          10        0.188642    0.207392
# 10         11        0.175457    0.202293
# 11         12        0.160409    0.197338
# 12         13        0.144026    0.192556
# 13         14        0.125838    0.189531
# 14         15        0.106008    0.184778
# 15         16        0.084545    0.184029
# 16         17        0.065156    0.180283
# 17         18        0.047583    0.179678
# 18         19        0.034465    0.177921
# 19         20        0.021856    0.177316
# 20         21        0.013079    0.176308
# 21         22        0.008268    0.175847
# 22         23        0.004533    0.175818
# 23         24        0.002189    0.173946
# 24         25        0.001066    0.173427
# 25         26        0.000643    0.175386
# 26         27        0.000336    0.174522
# 27         28        0.000221    0.173974
# 28         29        0.000115    0.174839
# 29         30        0.000067    0.173859
# 30         31        0.000086    0.174407
# 31         32        0.000086    0.174176
# 32         33        0.000058    0.174032
# 33         34        0.000048    0.173744
# 34         35        0.000048    0.173485
# 35         36        0.000058    0.174234
# 36         37        0.000067    0.175328
# 37         38        0.000058    0.175703
# 38         39        0.000048    0.174637
# 39         40        0.000067    0.174263
# 40         41        0.000067    0.174695
# 41         42        0.000067    0.174378
# 42         43        0.000067    0.174263
# 43         44        0.000067    0.174061
# 44         45        0.000067    0.174205
# 45         46        0.000067    0.174205
# 46         47        0.000067    0.174234
# 47         48        0.000067    0.174234
# 48         49        0.000067    0.174263
# 49         50        0.000067    0.174263
# 50         51        0.000067    0.174263
# 51         52        0.000067    0.174263
# 52         53        0.000067    0.174263
# 53         54        0.000067    0.174263
# 54         55        0.000067    0.174263
# 55         56        0.000067    0.174263
# 56         57        0.000067    0.174263
# 57         58        0.000067    0.174263
# 58         59        0.000067    0.174263
# 59         60        0.000067    0.174263

# %%
plt.figure()
plt.plot(errors_df['Max Depth'], errors_df['Training Error'])
plt.plot(errors_df['Max Depth'], errors_df['Test Error'])
plt.title('Training vs. Test Error')
plt.xlabel('Max. Depth')
plt.ylabel('Prediction Error (1 - Accuracy)')
plt.legend(['Training', 'Test'])

# %% [markdown]
# No max depth seems to have an impact. Best option is to keep at None

# %% [markdown]
# ### Number of estimators

# %%
# Experiment with max depth
def max_estimator_err(n):
    model = RandomForestClassifier(n_estimators=n, random_state=11, n_jobs=-1)
    model.fit(x_train, y_train)
    train_acc = 1 - model.score(x_train, y_train)
    test_acc = 1 - model.score(x_test, y_test)
    return {'Estimators': n, 'Training Error': train_acc, 'Test Error': test_acc}

# %%
errors_df = pd.DataFrame([max_estimator_err(md) for md in range(1, 1202, 50)])

# %%
errors_df
# Out:
#     Estimators  Training Error  Test Error
# 0            1        0.098642    0.270051
# 1           51        0.000230    0.176884
# 2          101        0.000058    0.174291
# 3          151        0.000048    0.173456
# 4          201        0.000048    0.172505
# 5          251        0.000048    0.172851
# 6          301        0.000048    0.172937
# 7          351        0.000048    0.172937
# 8          401        0.000048    0.172505
# 9          451        0.000048    0.172246
# 10         501        0.000048    0.171583
# 11         551        0.000048    0.171871
# 12         601        0.000048    0.171295
# 13         651        0.000048    0.171353
# 14         701        0.000048    0.171238
# 15         751        0.000048    0.170978
# 16         801        0.000048    0.171497
# 17         851        0.000048    0.171526
# 18         901        0.000048    0.171583
# 19         951        0.000048    0.171382
# 20        1001        0.000048    0.171699
# 21        1051        0.000048    0.171439
# 22        1101        0.000048    0.171612
# 23        1151        0.000048    0.171612
# 24        1201        0.000048    0.171756

# %%
plt.figure()
plt.plot(errors_df['Estimators'], errors_df['Training Error'])
plt.plot(errors_df['Estimators'], errors_df['Test Error'])
plt.title('Training vs. Test Error')
plt.xlabel('Number of estimators')
plt.ylabel('Prediction Error (1 - Accuracy)')
plt.legend(['Training', 'Test'])

# %% [markdown]
# More estimators = less testing error -> It seems like at 600 estimators it has the least amount of error. However, we keep at 200 because it is more worth and less computationally expensive

# %% [markdown]
# ### Max Leaf Nodes

# %%
# Experiment with max depth
def max_leaf_error(ml):
    model = RandomForestClassifier(max_leaf_nodes=ml, random_state=11, n_estimators=600, n_jobs=-1)
    model.fit(x_train, y_train)
    train_acc = 1 - model.score(x_train, y_train)
    test_acc = 1 - model.score(x_test, y_test)
    return {'Max Leaf Nodes': ml, 'Training Error': train_acc, 'Test Error': test_acc}

# %%
errors_df = pd.DataFrame([max_leaf_error(md) for md in range(2, 5003, 500)])

# %%
errors_df
# Out:
#     Max Leaf Nodes  Training Error  Test Error
# 0                2        0.293814    0.295172
# 1              502        0.173229    0.196186
# 2             1002        0.151372    0.189877
# 3             1502        0.134231    0.186708
# 4             2002        0.120950    0.184173
# 5             2502        0.108783    0.182098
# 6             3002        0.097941    0.180658
# 7             3502        0.088280    0.179967
# 8             4002        0.079158    0.179506
# 9             4502        0.071081    0.178555
# 10            5002        0.064215    0.178152

# %%
plt.figure()
plt.plot(errors_df['Max Leaf Nodes'], errors_df['Training Error'])
plt.plot(errors_df['Max Leaf Nodes'], errors_df['Test Error'])
plt.title('Training vs. Test Error')
plt.xlabel('Max Leaf Nodes')
plt.ylabel('Prediction Error (1 - Accuracy)')
plt.legend(['Training', 'Test'])

# %% [markdown]
# Conclusion: Lowest error when we do not restrict max leaf nodes

# %% [markdown]
# ### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = RandomForestClassifier(random_state=11, n_jobs=-1)

# %%
# Defining hyperparameters to tune
forest_param_grid = {
    'n_estimators': [200, 600],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3],
    'min_impurity_decrease': [0, 1e-07],
    'max_features': ['sqrt', None],
    'criterion': ['gini', 'entropy']
}

# Performing Grid Search with cross-validation
GS = GridSearchCV(estimator=model, param_grid=forest_param_grid, cv=5, verbose=2)
GS.fit(x_train, y_train)

# Best hyperparameters found
forest_best_params = GS.best_params_
print("Best hyperparameters:", forest_best_params, '\n')

# Evaluate the model with best hyperparameters on test set
forest_best_model = GS.best_estimator_
forest_accuracy = forest_best_model.score(x_test, y_test)
print(f"Accuracy on test set with best hyperparameters: {forest_accuracy}")
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  10.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.7s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.7s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  10.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  10.0s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=   9.7s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=   9.8s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   4.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.9s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  10.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=   3.1s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.6s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=sqrt, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=   9.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  43.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  13.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  40.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  40.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  14.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  14.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  14.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  13.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  40.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  41.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  41.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  41.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  41.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  13.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  13.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  39.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  39.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  39.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  39.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  39.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  13.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  39.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  40.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  40.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  39.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  39.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  13.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  13.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  13.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  13.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  39.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  40.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  39.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  39.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  40.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  15.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  42.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  14.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  43.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  42.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.2s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  14.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.6s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.3s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  42.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  13.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  13.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  13.7s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  13.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.5s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  41.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  40.9s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  14.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.4s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.1s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  41.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  40.8s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  14.0s
# [CV] END criterion=gini, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  13.9s
# ...
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  52.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  18.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  18.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  17.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  17.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  17.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  54.5s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  53.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  53.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  53.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=0, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  53.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  18.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  18.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  18.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  18.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  19.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  55.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  55.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  56.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  55.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  55.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  18.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  18.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  19.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  18.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  18.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  55.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  55.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  55.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  55.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=3, n_estimators=600; total time=  55.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  18.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  18.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  18.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=  18.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  55.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  54.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  55.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  55.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=1, min_samples_split=4, n_estimators=600; total time=  55.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  18.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  53.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  54.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  54.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  54.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  54.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  18.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  18.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  18.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  18.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  54.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  54.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  54.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  54.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=3, n_estimators=600; total time=  54.5s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  18.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  18.5s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  18.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=  18.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  54.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  54.5s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  54.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  54.2s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=2, min_samples_split=4, n_estimators=600; total time=  54.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  17.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  18.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  18.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  18.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  17.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  53.5s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  52.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  53.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  53.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=2, n_estimators=600; total time=  52.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  18.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  17.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  18.3s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  18.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=  17.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  52.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  53.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  53.0s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  52.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=  52.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  18.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  17.8s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  18.6s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  17.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=200; total time=  17.4s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  52.7s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  52.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  53.1s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  52.9s
# [CV] END criterion=entropy, max_features=None, min_impurity_decrease=1e-07, min_samples_leaf=3, min_samples_split=4, n_estimators=600; total time=  52.6s
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best hyperparameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 600}
#
# Accuracy on test set with best hyperparameters: 0.8279557501728508

# %% [markdown]
# ## Model with best hyperparameters

# %%
model = RandomForestClassifier(random_state=11, 
                               n_estimators=600, 
                               criterion='entropy', 
                               min_samples_leaf=1, 
                               min_samples_split=2, 
                               max_features='sqrt', 
                               n_jobs=-1
                               )
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=600, n_jobs=-1,
#                        random_state=11)

# %%
model.score(x_test, y_test)
# Out:
# 0.8279557501728508

# %%
model.score(x_val, y_val)
# Out:
# 0.8243546900207421

# %% [markdown]
# Even with the best hyperparameters, we see only a marginal 1% increase in the accuracy. This might have reached the limits of the modeling technique (random forests) or reached the limits of what is possible to predict given this amount of data, and the only way to further improve the model would be by getting more data.

# %% [markdown]
# ## Validation for random forests

# %%
from sklearn.metrics import confusion_matrix

# %%
def predict_and_plot(inputs, targets, name=''):
    preds = model.predict(inputs)
    
    accuracy = accuracy_score(targets, preds)
    print("Accuracy: {:.2f}%".format(accuracy * 100))
    
    cf = confusion_matrix(targets, preds, normalize='true')
    plt.figure()
    sns.heatmap(cf, annot=True)
    plt.xlabel('Prediction')
    plt.ylabel('Target')
    plt.title(f'{name} Confusion Matrix')
    
    return preds

# %%
train_preds = predict_and_plot(x_train, y_train, 'Training')
# Out:
# Accuracy: 100.00%

# %%
test_pred = predict_and_plot(x_test, y_test, 'Test')
# Out:
# Accuracy: 82.87%

# %%
val_pred = predict_and_plot(x_val, y_val, 'Validation')
# Out:
# Accuracy: 82.34%

# %% [markdown]
# ## Random Forests Feature Importance

# %%
importance_df = pd.DataFrame({
    'feature': x_train.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

# %%
plt.title('Feature Importance')
sns.barplot(data=importance_df, x='importance', y='feature');

# %% [markdown]
# ## Hyperparameter tuning with XGB Classifier

# %%
model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
model.score(x_test, y_test)
# Out:
# 0.8105554275178612

# %% [markdown]
# ### Number of estimators

# %%
# Experiment with max depth
def max_estimator_err(n):
    model = XGBClassifier(n_estimators=n, random_state=11, n_jobs=-1)
    model.fit(x_train, y_train)
    train_acc = 1 - model.score(x_train, y_train)
    test_acc = 1 - model.score(x_test, y_test)
    return {'Estimators': n, 'Training Error': train_acc, 'Test Error': test_acc}

# %%
errors_df = pd.DataFrame([max_estimator_err(md) for md in range(1, 2002, 100)])

# %%
errors_df
# Out:
#     Estimators  Training Error  Test Error
# 0            1        0.248132    0.253342
# 1          101        0.154071    0.188955
# 2          201        0.127470    0.186823
# 3          301        0.105335    0.186103
# 4          401        0.087071    0.185584
# 5          501        0.069094    0.184576
# 6          601        0.055035    0.186074
# 7          701        0.044616    0.185325
# 8          801        0.035608    0.184605
# 9          901        0.026946    0.184547
# 10        1001        0.019936    0.184490
# 11        1101        0.014539    0.184720
# 12        1201        0.011101    0.184000
# 13        1301        0.007894    0.183942
# 14        1401        0.005935    0.184345
# 15        1501        0.004100    0.183942
# 16        1601        0.002881    0.184345
# 17        1701        0.001949    0.184317
# 18        1801        0.001248    0.185210
# 19        1901        0.000845    0.184288
# 20        2001        0.000567    0.183913

# %%
plt.figure()
plt.plot(errors_df['Estimators'], errors_df['Training Error'])
plt.plot(errors_df['Estimators'], errors_df['Test Error'])
plt.title('Training vs. Test Error')
plt.xlabel('Number of estimators')
plt.ylabel('Prediction Error (1 - Accuracy)')
plt.legend(['Training', 'Test'])

# %% [markdown]
# Best is 500 estimators, after that it gets minimally better and overfits

# %% [markdown]
# ### Max Depth

# %%
# Experiment with max depth
def max_depth_error(md):
    model = XGBClassifier(max_depth=md, random_state=11, n_estimators=500, n_jobs=-1)
    model.fit(x_train, y_train)
    train_acc = 1 - model.score(x_train, y_train)
    test_acc = 1 - model.score(x_test, y_test)
    return {'Max Depth': md, 'Training Error': train_acc, 'Test Error': test_acc}

# %%
errors_df = pd.DataFrame([max_depth_error(md) for md in range(3, 31)])

# %%
errors_df
# Out:
#     Max Depth  Training Error  Test Error
# 0           3        0.175418    0.192614
# 1           4        0.149317    0.189790
# 2           5        0.116158    0.186650
# 3           6        0.069132    0.184518
# 4           7        0.030691    0.185527
# 5           8        0.006751    0.183568
# 6           9        0.000519    0.180082
# 7          10        0.000154    0.177028
# 8          11        0.000144    0.177431
# 9          12        0.000144    0.175847
# 10         13        0.000144    0.174291
# 11         14        0.000144    0.174637
# 12         15        0.000144    0.172909
# 13         16        0.000144    0.175617
# 14         17        0.000144    0.174176
# 15         18        0.000144    0.172246
# 16         19        0.000144    0.172188
# 17         20        0.000144    0.172822
# 18         21        0.000144    0.172304
# 19         22        0.000144    0.171958
# 20         23        0.000144    0.173197
# 21         24        0.000144    0.174090
# 22         25        0.000144    0.173254
# 23         26        0.000144    0.173283
# 24         27        0.000144    0.172505
# 25         28        0.000144    0.172188
# 26         29        0.000144    0.171468
# 27         30        0.000144    0.172851

# %%
plt.figure()
plt.plot(errors_df['Max Depth'], errors_df['Training Error'])
plt.plot(errors_df['Max Depth'], errors_df['Test Error'])
plt.title('Training vs. Test Error')
plt.xlabel('Max. Depth')
plt.ylabel('Prediction Error (1 - Accuracy)')
plt.legend(['Training', 'Test'])

# %% [markdown]
# Max depth of 28 seems to have the best effect and lowest error

# %% [markdown]
# ### Max Leaf Nodes

# %%
# Experiment with max depth
def max_leaf_error(ml):
    model = XGBClassifier(max_leaf_nodes=ml, random_state=11, n_estimators=500, max_depth=28, n_jobs=-1)
    model.fit(x_train, y_train)
    train_acc = 1 - model.score(x_train, y_train)
    test_acc = 1 - model.score(x_test, y_test)
    return {'Max Leaf Nodes': ml, 'Training Error': train_acc, 'Test Error': test_acc}

# %%
errors_df = pd.DataFrame([max_leaf_error(md) for md in range(2, 5003, 500)])
# Out:
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:38:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:39:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:39:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:39:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:39:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:40:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:40:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:40:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:40:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:41:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:41:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
errors_df
# Out:
#     Max Leaf Nodes  Training Error  Test Error
# 0                2        0.000144    0.172188
# 1              502        0.000144    0.172188
# 2             1002        0.000144    0.172188
# 3             1502        0.000144    0.172188
# 4             2002        0.000144    0.172188
# 5             2502        0.000144    0.172188
# 6             3002        0.000144    0.172188
# 7             3502        0.000144    0.172188
# 8             4002        0.000144    0.172188
# 9             4502        0.000144    0.172188
# 10            5002        0.000144    0.172188

# %%
plt.figure()
plt.plot(errors_df['Max Leaf Nodes'], errors_df['Training Error'])
plt.plot(errors_df['Max Leaf Nodes'], errors_df['Test Error'])
plt.title('Training vs. Test Error')
plt.xlabel('Max Leaf Nodes')
plt.ylabel('Prediction Error (1 - Accuracy)')
plt.legend(['Training', 'Test'])

# %% [markdown]
# Keep at 3000

# %% [markdown]
# ## XGB Model with best hyperparameters

# %%
model = XGBClassifier(random_state=11, n_estimators=500, max_depth=28, max_leaf_nodes=3000, n_jobs=-1)

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\ethan\PycharmProjects\fire-guard\model\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:49:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "max_leaf_nodes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=28, max_leaf_nodes=3000,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
model.score(x_test, y_test)
# Out:
# 0.8278117077667665

# %%
model.score(x_val, y_val)
# Out:
# 0.8220212030421756

# %% [markdown]
# ## Saving Random Forests model to drive

# %%
import joblib

# %%
model_disk = {
    'model': model,
    'scaler': scaler,
    'input_cols': input_col,
    'target_col': target_col,
}

# %%
joblib.dump(model_disk, 'model.joblib')
# Out:
# ['model.joblib']
